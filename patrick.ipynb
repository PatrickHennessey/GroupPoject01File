# %%
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Input Files (CSV)

minneapolis = "DataFiles/Minneapolis_Crime_Data_2010-2018.csv"
indianapolis = "DataFiles/Indianapolis_Crime_Data_2007-2019.csv"
atlanta = "DataFiles/Atlanta-2009-2018.csv"
dallas = "DataFiles/Dallas_Fort_WorthCrime_Data.csv"
miami = "DataFiles/Miami_Jail_Bookings__May_29_2015_to_current.csv"

# Output Files (CSV)
minne_out = "DataFiles/minneaplis_sorted.csv"
india_out = "DataFiles/indianapolis_sorted.csv"
atlanta_out = "DataFiles/atlanta_sorted.csv"
dallas_out = "DataFiles/dallas_sorted.csv"
miami_out = "DataFiles/miami_sorted.csv"

# %%
minne_start_df = pd.read_csv(minneapolis)
# minne_start_df.columns
minne_sorted_df = minne_start_df.loc[:, ["Offense", "Description", "Description", "Offense", "BeginDate","Time", "UCRCode", "X", "Y"]]
minne_sorted_df.head(20)
# Out:
#    Offense           Description           Description Offense  \
# 0   SHOPLF           Shoplifting           Shoplifting  SHOPLF
# 1    BURGD  Burglary Of Dwelling  Burglary Of Dwelling   BURGD
# 2    BURGB  Burglary Of Business  Burglary Of Business   BURGB
# 3    ASLT3  Aslt-sgnfcnt Bdly Hm  Aslt-sgnfcnt Bdly Hm   ASLT3
# 4   AUTOTH   Motor Vehicle Theft   Motor Vehicle Theft  AUTOTH
# 5    BURGD  Burglary Of Dwelling  Burglary Of Dwelling   BURGD
# 6   ROBBIZ   Robbery Of Business   Robbery Of Business  ROBBIZ
# 7    THEFT           Other Theft           Other Theft   THEFT
# 8     TFMV  Theft From Motr Vehc  Theft From Motr Vehc    TFMV
# 9   ROBPAG       Robbery Per Agg       Robbery Per Agg  ROBPAG
# 10  ROBPAG       Robbery Per Agg       Robbery Per Agg  ROBPAG
# 11  ROBPAG       Robbery Per Agg       Robbery Per Agg  ROBPAG
# 12   BURGD  Burglary Of Dwelling  Burglary Of Dwelling   BURGD
# 13   BURGD  Burglary Of Dwelling  Burglary Of Dwelling   BURGD
# ...

# %%
india_start_df = pd.read_csv(indianapolis)
# india_start_df.columns
india_sorted_df = india_start_df.loc[:, ["CRIME", "DATE_","TIME", "UCR", "X_COORD", "Y_COORD"]]
india_sorted_df.head(20)
# Out:
#                 CRIME                     DATE_   TIME  UCR    X_COORD  \
# 0   CRIMINAL HOMICIDE  2007-01-01T00:00:00.000Z  04:24  110  197257.63
# 1   CRIMINAL HOMICIDE  2007-01-01T00:00:00.000Z  10:39  110  194654.40
# 2   CRIMINAL HOMICIDE  2007-01-04T00:00:00.000Z  18:01  110  210918.07
# 3   CRIMINAL HOMICIDE  2007-01-10T00:00:00.000Z  07:06  110  237903.29
# 4   CRIMINAL HOMICIDE  2007-01-10T00:00:00.000Z  18:19  110  192426.71
# 5   CRIMINAL HOMICIDE  2007-01-11T00:00:00.000Z  00:01  110  197313.94
# 6   CRIMINAL HOMICIDE  2007-01-18T00:00:00.000Z  01:00  110  181659.23
# 7   CRIMINAL HOMICIDE  2007-01-19T00:00:00.000Z  18:40  110  208479.77
# 8   CRIMINAL HOMICIDE  2007-01-26T00:00:00.000Z  23:15  110  200528.18
# 9   CRIMINAL HOMICIDE  2007-02-08T00:00:00.000Z  02:43  110  206124.87
# 10  CRIMINAL HOMICIDE  2007-02-12T00:00:00.000Z  21:42  110  166290.47
# 11  CRIMINAL HOMICIDE  2007-02-17T00:00:00.000Z  10:34  110  200043.11
# ...

# %%
atlanta_start_df = pd.read_csv(atlanta)
# atlanta_start_df.columns
atlanta_sorted_df = atlanta_start_df.loc[:, ["UCR Literal", "Report Date","Occur Time", "UCR #", "Latitude", "Longitude"]]
atlanta_sorted_df.head(20)
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#              UCR Literal Report Date  Occur Time  UCR #  Latitude  Longitude
# 0    LARCENY-NON VEHICLE  2009-01-01        1145    630  33.68845  -84.49328
# 1    LARCENY-NON VEHICLE  2009-01-01        1330    630  33.75320  -84.39201
# 2    LARCENY-NON VEHICLE  2009-01-01        1500    630  33.75735  -84.50282
# 3    LARCENY-NON VEHICLE  2009-01-01        1450    630  33.84676  -84.36212
# 4    LARCENY-NON VEHICLE  2009-01-01        1600    630  33.68677  -84.49773
# 5    LARCENY-NON VEHICLE  2009-01-01        1645    630  33.75786  -84.34875
# 6    LARCENY-NON VEHICLE  2009-01-01        1740    630  33.70827  -84.45385
# 7    LARCENY-NON VEHICLE  2009-01-01        1627    630  33.84676  -84.36212
# ...

# %%
dallas_start_df = pd.read_csv(dallas)
# dallas_start_df.columns
dallas_sorted_df = dallas_start_df.loc[:, ["Description", "Nature Of Call", "Reported Date", "Location"]]
dallas_sorted_df.head(20)
# Out:
#                                           Description  \
# 0   GC 080 Public Intoxication 90E DRUNKENNESS 000...
# 1   PC 30.03 Burglary Coin Oper Col Machine 23E THEFT
# 2   PC 30.02(C)(2) Burglary Habitation 220 BURGLAR...
# 3   PC 32.51 Fraud Use Poss of ID Info 26F Identit...
# 4   PC 22.01(A)(1) Assault Causes B/I 13B SIMPLE A...
# 5   PC 31.03 - Others Theft - Others 23H ALL OTHER...
# 6   HSC 481.117(B) Poss CS PG 3 <28G 35A DRUG/NARC...
# 7   PC 31.03 - Others Theft - Others 23H ALL OTHER...
# 8   PC 31.03  (F) Theft Prop<$2500 2+Conv ENH IAT 23H
# 9   PC 22.01 (C)(1) Aslt Against Elderly/Disabled Ind
# 10  CCP 62.10(B)(3) FAIL TO COMPLY SEX OFF DUTY TO...
# 11  PC 30.04(A) Burglary Vehicle 23F THEFT FROM MOTOR
# 12  GC 514 Graffiti - Private Property 290 DESTRUC...
# 13  GC 109 Consume Alcohol Where Prohibited 90G LI...
# 14  HSC 481.115(B) Poss CS PG 1 <1G 35A DRUG/NARCOTIC
# 15  PC 30.05(A) Criminal Trespass 90J TRESPASS OF ...
# ...

# %%
miami_start_df = pd.read_csv(miami)
# miami_start_df.columns
miami_sorted_df = miami_start_df.loc[:, ["Charge1", "ChargeCode1", "BookDate", "Zip1"]]
miami_sorted_df.head(20)
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                  Charge1 ChargeCode1                  BookDate       Zip1
# 0                BATTERY     7840300  2015-06-16T04:00:00.000Z  331436901
# 1   DOM VIO/INJ VIOLATIO         NaN  2015-06-16T04:00:00.000Z  331657744
# 2    CANN/TRF/25-2000LBS  89313501A1  2015-06-16T04:00:00.000Z      33165
# 3                    NaN         NaN  2015-06-16T04:00:00.000Z  331754816
# 4                    NaN         NaN  2015-06-16T04:00:00.000Z      33167
# 5          BENCH WARRANT         NaN  2015-06-16T04:00:00.000Z      33167
# 6                BATTERY     7840300  2015-06-16T04:00:00.000Z      33189
# 7   NO VALID DRIVERS LIC    32203001  2015-06-16T04:00:00.000Z      33127
# ...

# %%
# minne_start_df.head(10)
# india_start_df.head(10)
# atlanta_start_df.head(10)
# dallas_start_df.head(10)
# miami_start_df.head(10)

# %% [markdown]
# # Export DataFrame to csv file
# weather_df.to_csv(weather_data_csv)

# %%
# Export DataFrame to csv file
minne_sorted_df.to_csv(minne_out)
india_sorted_df.to_csv(india_out)
atlanta_sorted_df.to_csv(minne_out)
minne_sorted_df.to_csv(minne_out)
minne_sorted_df.to_csv(minne_out)
