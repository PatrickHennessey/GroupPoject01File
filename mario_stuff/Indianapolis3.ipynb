# %%
# %matplotlib notebook

# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x_axis = range(1,10)
assault_simple_number = [42 , 0 , 0 , 0 , 0 , 0 , 0 , 0 , 0]
vehicle_theft_number = [27 , 14 , 24 , 30 , 30 , 23 , 19 , 25 , 10]
stolen_vehicle_number = [0 , 0 , 0 , 0 , 1 , 1 , 0 , 0 , 0]
assault_other_weapon_number = [4 , 13 , 11 , 9 , 17 , 16 , 6 , 11 , 13]
assault_hand_number = [2 , 11 , 8 , 5 , 10 , 23 , 10 , 7 , 10]
assault_gun_number = [4 , 4 , 7 , 4 , 2 , 3 , 3 , 3 , 7]
assault_knife_number =[1 , 1 , 1 , 4 , 3 , 6 , 1 , 5 , 6]
attempt_stolen_vehicle_number = [1 , 3 , 0 , 2 , 0 , 2 , 1 , 1 , 2]

# %%
stolen_vehicle, = plt.plot(x_axis, stolen_vehicle_number, color="red", label="Stolen Vehicle")
other_weapon, = plt.plot(x_axis,assault_other_weapon_number, color="blue", label="Assault o. Weapon")
assault_knife, = plt.plot(x_axis,assault_knife_number, color="green", label="Assault Knife")

assault_simple, = plt.plot(x_axis, assault_simple_number, color="red", label="Assault Simple")
vehicle_theft, = plt.plot(x_axis,vehicle_theft_number, color="blue", label="Vehicle Theft")
stolen_vehicle, = plt.plot(x_axis,stolen_vehicle_number, color="green", label="Stolen Vehicle")
assault_other, = plt.plot(x_axis, assault_other_weapon_number, color="black", label="Assault Other")
assault_hand, = plt.plot(x_axis,assault_hand_number, color="yellow", label="Assault Hand")
assault_gun, = plt.plot(x_axis,assault_gun_number, color="purple", label="Assault Gun")
assault_knife, = plt.plot(x_axis,assault_knife_number, color="maroon", label="Assault Knife")
attempt_stolen_vehicle, = plt.plot(x_axis,attempt_stolen_vehicle_number, color="pink", label="At Stolen Vehicle")

plt.title("Indianapolis Snap Shot Jan-Feb 2012")
plt.xlabel("First 9 Weekends 2012")
plt.ylabel("Number of Incidents")

plt.legend(handles=[assault_simple, vehicle_theft, stolen_vehicle, assault_other, assault_hand,assault_gun,assault_knife, attempt_stolen_vehicle,], loc="best")
plt.savefig("Indianapolis2012.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
